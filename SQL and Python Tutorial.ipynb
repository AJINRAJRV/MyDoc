# %%
a=1
b=2
c=a+b
print(c)
# Out:
# 3

# %%
a = 1
b = 2
print(f"The value of variable a and b are {a} and {b} respectevely")
# Out:
# The value of variable a and b are 1 and 2 respectevely

# %%
a = 10;
b = 20;
print("value of a {} and value of b {}".format(a,b))
print("value of a {} and value of b {}".format(b,a))
print("value of a {1} and value of b {0}".format(b,a)) #indexing
print(a,b)
# Out:
# value of a 10 and value of b 20
# value of a 20 and value of b 10
# value of a 10 and value of b 20
# 10 20

# %%
#string value
my = "country";
name_is = "India"
print("I love my {1} , name_is {0}".format(name_is,my))
# Out:
# I love my country , name_is India

# %%
#print without reference variable or pass by value 
print("my name is {},{} from {}".format("Bill","Gate","Microsoft"))
# Out:
# my name is Bill,Gate from Microsoft

# %%
#input enter by user

num = input ("Enter a value : ")
print(num)
# Out:
# Enter a value :  Ajin
# Ajin

# %%
num = input (" ENTER A NUMBER : ");
print(num);
# Out:
#  ENTER A NUMBER :  10
# 10

# %%
#enter multiple value
x= input("Enter 1st digit of PIN no: "),input("Enter 2nd digit of PIN no: "),input("Enter 3rd digit of PIN no: "),input("Enter 4rth digit of PIN no: ")
print(x)
# Out:
# Enter 1st digit of PIN no:  1
# Enter 2nd digit of PIN no:  2
# Enter 3rd digit of PIN no:  3
# Enter 4rth digit of PIN no:  4
# ('1', '2', '3', '4')

# %% [markdown]
# # OPERATORS

# %%
#Logical Operators
a = True
b = False
print(not b)
# Out:
# True

# %%
#Identity Operators
A = 5
B = 5

print(id(A))
print(id(B))
print(type(A))
print(type(B))
print(A is not B)
# Out:
# 140719505920936
# 140719505920936
# <class 'int'>
# <class 'int'>
# False

# %%
L1= [1,2,3]
L2= [1,2,3]

print(id(L1))
print(id(L2))
print(L1 is L2)  #compares address
print(L1 == L2)  #compares values
# Out:
# 1654563688448
# 1654563290240
# False
# True

# %%
# MEMBERSHIP OPERATOR

L1= [1,2,3,4]
print(L1)
print (5 in L1)
# Out:
# [1, 2, 3, 4]
# False

# %%
x = 10
if (x>0):
    print("x is positive")
else:
    print("x is negative");
# Out:
# x is positive

# %%
#case 1

num = 10
if None : #(None, 0 , -1) None : it will not allow to get into loop
    print("number is positive")

print("This will print always") # this will run default
# Out:
# This will print always

# %%
#NESTED LOOP
age = 33
if (age>=10 and age<=20):
    print("1st Division");
elif(age>20 and age<=30):
    print("Second Division")
else:
    print("Fail")
# Out:
# Fail

# %%
A = 100
B = 20
C = 30

if (A>B and A>C):
    print("A is Biggest")
elif(B>A and B>C):
    print("B is Biggest")
else:
    print("C is biggest")
# Out:
# A is Biggest

# %%
a = [10,20,30,40,50]

product = 2

for ele in a:
    product *= ele
    print(product)
# Out:
# 20
# 400
# 12000
# 480000
# 24000000

# %%
product = 2
for i in range(10,51,10):
    product *= i
    print(product)
else:
    print("_______________")
    print("End of the loop")
# Out:
# 20
# 400
# 12000
# 480000
# 24000000
# _______________
# End of the loop

# %%
for i in range(2,11,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#odd or even
odd=[]
even=[]
for i in range(1,11):
    if i%2==0:
        even.append(i)
    else:
        odd.append(i)

print(odd)
print(even)
# Out:
# [1, 3, 5, 7, 9]
# [2, 4, 6, 8, 10]

# %%
#PRIME NUMBER
#FIBONACCI
#REVERESE A STRING
#PALINDROME

# %%
#Reverse
s = input("Enter a string: ")
def revstring(s):
    s[::-1]

print("Reversed String is :",revstring(s))
# Out:
# Enter a string:  ki
# Reversed String is : None

# %%
s= "ajin"
print(s[::-1])
# Out:
# nija

# %%
#palindrome
s = "MALAYALAM"
if (s == s[::-1]):
    print("Palindrome String")
else:
    print("Not a Palindrome String")
# Out:
# Palindrome String

# %%
n = int(input("Enter a number : "))

if str(n)==str((n)[::-1]):
    print("Palindrome String")
else:
    print("Not a Palindrome String")
# Out:
# Enter a number :  303
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 3
#       1 n = int(input("Enter a number : "))
# ----> 3 if str(n)==str((n)[::-1]):
#       4     print("Palindrome String")
#       5 else:
#
# TypeError: 'int' object is not subscriptable

# %%
def show_name(name):
    """
    this fn shows name
    """
    print("name is " +str(name))

show_name("ajin")
# Out:
# name is ajin

# %%
#local variable 

def get_sum(lst):
    """
    this fn will return the sum of elements inside the list
    """
    result = 0
    for num in lst:
        result +=num
        print(result)
    return result

lst1=get_sum([1,2,3,4,5])
print("Sum of the numbers in lst1 is : ",lst1)
# Out:
# 1
# 3
# 6
# 10
# 15
# Sum of the numbers in lst1 is :  15

# %%
global_var = "This is a global variable"

def global_test():
    local_variable = "this is a local variable"
    global_var="Global variable Inside the function"
    #print(local_variable)
    print(global_var)

print(global_var)

global_test()
# Out:
# This is a global variable
# Global variable Inside the function

# %%
num1=24
num2=36
while num2!=0:
    remainder=num1%num2
    num1,num2=num2,remainder

print(num2)
# Out:
# 0

# %%
num = -100
print(abs(num))
# Out:
# 100

# %%
lst = [1,2,3,4]
lst2 = [0]
print(all(lst))
print(all(lst2))
# Out:
# True
# False

# %%
lst = []
print(type(lst))
print(dir(lst))
lst2 = tuple(lst)
print(type(lst2))

print(dir(lst2))
# Out:
# <class 'list'>
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
# <class 'tuple'>
# ...

# %%
#DIVMOD()
#The divmod() method takes two no. & return a pair of no. (a tuple) consisting of their
print(divmod(13,2))
# Out:
# (6, 1)

# %%
#Enumerate()

#this mehtod adds counter to an iterable and returns it
#Syntax enumerate(iterate, start=0) ,ie 10 having position 0, 20 having 1

lst = [10,20,30,40,50]

for index , num in

# %%
lst1_list = range(-10,10) #create a list with number from -10 to 10

#print(list(lst1_list))
#print(type(lst1_list))

#lst2_postive

lst2_positive = list(filter(lambda n:n%2 !=0, lst1_list))

#print i in lst2_positive:
for i in lst2_positive:
    print(i)
# Out:
# -9
# -7
# -5
# -3
# -1
# 1
# 3
# 5
# 7
# 9

# %%
#MAP

def hallsquare(num):
    return (num**2)

#using map() function

squared = list(map(lambda x: x **2, [1,2,3,4])) 
print(squared)
# Out:
# [1, 4, 9, 16]

# %%
#REDUCE ()

from functools import reduce
lst=[1,2,3,4]
def multiply(x,y):
    return x*y;

product = reduce(lambda x,y: x*y, lst)

print(product)
# Out:
# 24

# %%
#reduce , It work on double argument , Map work on single argument, filter work on single argument

# %%
print("CALCULATOR")
print("Operations")
print("1.Addition,2.Substraction,3.Multiplication,4.Division")
choice=int(input("Enter your choice number : "))

num1=int(input("Enter the first number :"))
num2=int(input("Enter the second number : "))


def addi(num1,num2):
    return num1+num2
def subs(num1,num2):
    return num1-num2;
def multi(num1,num2):
    return num1*num2;
def divi(num1,num2):
    return num1/num2

if choice == 1:
    result=addi(num1,num2)
    print(result)
    #print("Result is : ", lambda x:num1+num2);
    
elif choice ==2 :
    result=subs(num1,num2)
    print(result)
    #print("Result is : ", lambda x:num1-num2);
elif choice == 3:
    result=multi(num1,num2)
    print(result)
    #print("Result is : ", lambda x:num1*num2);
elif choice == 4:
    result=divi(num1,num2)
    print(result)
    #print("Result is : ", lambda x:num1/num2);
else:
    print("Invalid Choice")
# Out:
# CALCULATOR
# Operations
# 1.Addition,2.Substraction,3.Multiplication,4.Division
# Enter your choice number :  4
# Enter the first number : 3
# Enter the second number :  3
# 1.0

# %% [markdown]
# #30/04/2025

# %%
#DEFAULT ARGUMENT

#case1
def say(x,y,z):
    prod=x+y+z
    return prod

say(1,2,3)
# Out:
# 6

# %%
#case 2
def say(x=5,y):    #error
    prod=x+y  
    return prod

say(3)


#when you have first parameter as default we have to give argument values to every parameter
# Out:
#   Cell In[16], line 2
#     def say(x=5,y):
#                 ^
# SyntaxError: non-default argument follows default argument

# %%
#case3
def say(x,y=5):
    prod= x*y
    return prod

say(1)
# Out:
# 5

# %%
#case4
def say(x=5,y=5):
    prod = x*y
    return prod

say(6,6)
# Out:
# 36

# %%
#case5
def say(x,y=4,z=5):
    prod= x*y*z
    return prod

say(1)
# Out:
# 20

# %%
#case6
def say(x,y=10,z):   #ERROR :non-default argument follows default argument
    prod = x*y*z
    return prod

say(1,z=10)
# Out:
#   Cell In[41], line 2
#     def say(x,y=10,z):   #ERROR :non-default argument follows default argument
#                    ^
# SyntaxError: non-default argument follows default argument

# %% [markdown]
# #FILE HANDLING

# %% [markdown]
# #import os

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.getenv("C:\\Users\\Administrator")  #tell your home directory(os.getcwd)
lst = open("test.txt",'w')  #creates a file on home directory with write mode
lst.write("Hello Ajin Welcome to Banglore \n") #this will write 1st line in file
lst.write("This is second line") #this will write 2nd line in file
lst.close() #always run this command make sure file get back to disk & its safe

# %%
lst = open("test.txt", 'r')
lst.read()
# Out:
# 'Hello Ajin Welcome to Banglore \nThis is second line'

# %%
lst = open("test.txt", 'r')
lst.read(4)
# Out:
# 'Hell'

# %%
lst = open("test.txt", 'r')
lst.read(8)
lst.read(4)
# Out:
# 'in W'

# %%
ajin = open("test.txt", 'r')
ajin.tell()
# Out:
# 0

# %%
ajin = open("test.txt", 'r')
ajin.seek(0)
# Out:
# 0

# %%
ajin.tell()
# Out:
# 0

# %%
ajin.seek(5)
# Out:
# 5

# %%
ajin.tell()
# Out:
# 5

# %%
ajin.read(10)
# Out:
# ' Ajin Welc'

# %%
ajin.seek(0)
# Out:
# 0

# %%
ajin.read(10)
# Out:
# 'Hello Ajin'

# %%
ajin.seek(0)
for line in ajin:
    print(line)
# Out:
# Hello Ajin Welcome to Banglore
#
# This is second line

# %%
ajin.readline()
# Out:
# ''

# %%
ajin = open("test.txt", 'r')
ajin.readline()
# Out:
# 'Hello Ajin Welcome to Banglore \n'

# %%
ajin = open("test.txt", 'r')
ajin.readlines()
# Out:
# ['Hello Ajin Welcome to Banglore \n', 'This is second line']

# %%
ajin.readline()
ajin.close()

# %%
#rename
#remove

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.getenv('C:\\Users\\Administrator')

# %%
os.chdir('C:\\Users\\Administrator')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.listdir(os.getcwdb())
# Out:
# [b'.ipynb_checkpoints',
#  b'.ipython',
#  b'.jupyter',
#  b'.scala_history',
#  b'3D Objects',
#  b'airflow_venv',
#  b'AppData',
#  b'Application Data',
#  b'Contacts',
#  b'Cookies',
#  b'Desktop',
#  b'Documents',
#  b'Downloads',
#  b'Favorites',
#  b'grafana-server.exe',
#  b'Links',
#  b'Local Settings',
#  b'Music',
#  b'My Documents',
#  b'NetHood',
#  b'NTUSER.DAT',
#  b'ntuser.dat.LOG1',
#  b'ntuser.dat.LOG2',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  b'ntuser.ini',
#  b'OneDrive',
#  b'Pictures',
#  b'PrintHood',
#  b'Recent',
#  b'Saved Games',
#  b'Searches',
#  b'SendTo',
#  b'Start Menu',
#  b'Templates',
#  b'test.txt',
#  b'Untitled.ipynb',
#  b'untitled.py',
#  b'Untitled1.ipynb',
#  b'Untitled2.ipynb',
#  b'Videos']

# %%
ajin = open("test.txt",'r')
ajin.rename("test.txt","newtest.txt")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 2
#       1 ajin = open("test.txt",'r')
# ----> 2 ajin.rename("test.txt","newtest.txt")
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'rename'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.mkdir('AJIN')

# %%
os.listdir(os.getcwdb())
# Out:
# [b'.ipynb_checkpoints',
#  b'.ipython',
#  b'.jupyter',
#  b'.scala_history',
#  b'3D Objects',
#  b'airflow_venv',
#  b'AJIN',
#  b'AppData',
#  b'Application Data',
#  b'Contacts',
#  b'Cookies',
#  b'Desktop',
#  b'Documents',
#  b'Downloads',
#  b'Favorites',
#  b'grafana-server.exe',
#  b'Links',
#  b'Local Settings',
#  b'Music',
#  b'My Documents',
#  b'NetHood',
#  b'NTUSER.DAT',
#  b'ntuser.dat.LOG1',
#  b'ntuser.dat.LOG2',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  b'ntuser.ini',
#  b'OneDrive',
#  b'Pictures',
#  b'PrintHood',
#  b'Recent',
#  b'Saved Games',
#  b'Searches',
#  b'SendTo',
#  b'Start Menu',
#  b'Templates',
#  b'test.txt',
#  b'Untitled.ipynb',
#  b'untitled.py',
#  b'Untitled1.ipynb',
#  b'Untitled2.ipynb',
#  b'Videos']

# %%
os.chdir('C:\\Users\\Administrator\\AJIN')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\AJIN'

# %%
os.getenv('C:\\Users\\Administrator\\AJIN')
new = open("newfile.txt",'w')
new.write("Hello this is an assignment")
# Out:
# 27

# %%
import shutil

os.chdir("C:\\Users\\Administrator\\AJIN")
ajin = open("newfile.txt",'r')
ajin.read()
# Out:
# 'Hello this is an assignment'

# %%
ajin.close()

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.chdir("C:\\Users\\Administrator")

# %%
os.listdir(os.getcwdb())
# Out:
# [b'.ipynb_checkpoints',
#  b'.ipython',
#  b'.jupyter',
#  b'.scala_history',
#  b'3D Objects',
#  b'airflow_venv',
#  b'AJIN',
#  b'AppData',
#  b'Application Data',
#  b'Contacts',
#  b'Cookies',
#  b'Desktop',
#  b'Documents',
#  b'Downloads',
#  b'Favorites',
#  b'grafana-server.exe',
#  b'Links',
#  b'Local Settings',
#  b'Music',
#  b'My Documents',
#  b'NetHood',
#  b'NTUSER.DAT',
#  b'ntuser.dat.LOG1',
#  b'ntuser.dat.LOG2',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  b'ntuser.ini',
#  b'OneDrive',
#  b'Pictures',
#  b'PrintHood',
#  b'Recent',
#  b'Saved Games',
#  b'Searches',
#  b'SendTo',
#  b'Start Menu',
#  b'Templates',
#  b'test.txt',
#  b'Untitled.ipynb',
#  b'untitled.py',
#  b'Untitled1.ipynb',
#  b'Untitled2.ipynb',
#  b'Videos']

# %%
shutil.rmtree('AJIN')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 shutil.rmtree('AJIN')
#
# File C:\Program Files\Python311\Lib\shutil.py:758, in rmtree(path, ignore_errors, onerror, dir_fd)
#     756     # can't continue even if onerror hook returns
#     757     return
# --> 758 return _rmtree_unsafe(path, onerror)
#
# File C:\Program Files\Python311\Lib\shutil.py:621, in _rmtree_unsafe(path, onerror)
#     619             os.unlink(fullname)
#     620         except OSError:
# --> 621             onerror(os.unlink, fullname, sys.exc_info())
#     622 try:
#     623     os.rmdir(path)
#
# File C:\Program Files\Python311\Lib\shutil.py:619, in _rmtree_unsafe(path, onerror)
#     617 else:
#     618     try:
# --> 619         os.unlink(fullname)
#     620     except OSError:
#     621         onerror(os.unlink, fullname, sys.exc_info())
#
# ...

# %%
os.mkdir('NEWDIR')

# %%
os.listdir(os.getcwdb())
# Out:
# [b'.ipynb_checkpoints',
#  b'.ipython',
#  b'.jupyter',
#  b'.scala_history',
#  b'3D Objects',
#  b'airflow_venv',
#  b'AJIN',
#  b'AppData',
#  b'Application Data',
#  b'Contacts',
#  b'Cookies',
#  b'Desktop',
#  b'Documents',
#  b'Downloads',
#  b'Favorites',
#  b'grafana-server.exe',
#  b'Links',
#  b'Local Settings',
#  b'Music',
#  b'My Documents',
#  b'NetHood',
#  b'NEWDIR',
#  b'NTUSER.DAT',
#  b'ntuser.dat.LOG1',
#  b'ntuser.dat.LOG2',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  b'ntuser.ini',
#  b'OneDrive',
#  b'Pictures',
#  b'PrintHood',
#  b'Recent',
#  b'Saved Games',
#  b'Searches',
#  b'SendTo',
#  b'Start Menu',
#  b'Templates',
#  b'test.txt',
#  b'Untitled.ipynb',
#  b'untitled.py',
#  b'Untitled1.ipynb',
#  b'Untitled2.ipynb',
#  b'Videos']

# %%
os.chdir('C:\\Users\\Administrator\\NEWDIR')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\NEWDIR'

# %%
import shutil

os.chdir('C:\\Users\\Administrator\\NEWDIR')
ajin = open("test.txt","w")
ajin.write("this is 1st module\n")
ajin.close()

# %%
ajin = open("test.txt","r")
ajin.read()
# Out:
# 'this is 1st module\n'

# %%
ajin.close()

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\NEWDIR'

# %%
os.chdir("C:\\Users\\Administrator")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
shutil.rmtree('C:\\Users\\Administrator\\NEWDIR')

# %%
os.listdir(os.getcwdb())
# Out:
# [b'.ipynb_checkpoints',
#  b'.ipython',
#  b'.jupyter',
#  b'.scala_history',
#  b'3D Objects',
#  b'airflow_venv',
#  b'AJIN',
#  b'AppData',
#  b'Application Data',
#  b'Contacts',
#  b'Cookies',
#  b'Desktop',
#  b'Documents',
#  b'Downloads',
#  b'Favorites',
#  b'grafana-server.exe',
#  b'Links',
#  b'Local Settings',
#  b'Music',
#  b'My Documents',
#  b'NetHood',
#  b'NTUSER.DAT',
#  b'ntuser.dat.LOG1',
#  b'ntuser.dat.LOG2',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  b'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  b'ntuser.ini',
#  b'OneDrive',
#  b'Pictures',
#  b'PrintHood',
#  b'Recent',
#  b'Saved Games',
#  b'Searches',
#  b'SendTo',
#  b'Start Menu',
#  b'Templates',
#  b'test.txt',
#  b'Untitled.ipynb',
#  b'untitled.py',
#  b'Untitled1.ipynb',
#  b'Untitled2.ipynb',
#  b'Videos']

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
#import module sys to get the type of exception
import sys

lst = ['b',0,2]
for entry in lst:
    try:
        print("value is:",entry)
        k = 1/int(entry)

    except:
        print("oops" , sys.exc_info(),"occured");
        print("next entry")

print("The reciprocal of", entry ,"is" , k)
# Out:
# value is: b
# oops (<class 'ValueError'>, ValueError("invalid literal for int() with base 10: 'b'"), <traceback object at 0x000001D0874811C0>) occured
# next entry
# value is: 0
# oops (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x000001D087481140>) occured
# next entry
# value is: 2
# The reciprocal of 2 is 0.5

# %%
import sys

lst = ['b',0,2]

for entry in lst:
    try:
        print("Value is ",entry)
        k = 1/int(entry)
    except(ValueError):
        print("Value Error Occured")
    except(ZeroDivisionError):
        print("Cant Divide by zero")
    except:
        print("Other error")

print("The reciprocal of ",entry ,"is", k)
# Out:
# Value is  b
# Value Error Occured
# Value is  0
# Cant Divide by zero
# Value is  2
# The reciprocal of  2 is 0.5

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
import os
os.chdir('C:\\Users\\Administrator')
try:
    f = open('prwa.txt')
    #perform file operation


finally:
    print("final closed")
    f.close()
# Out:
# final closed
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       3 try:
# ----> 4     f = open('prwa.txt')
#       5     #perform file operation
#       6
#       7
#       8 finally:
#
# File C:\Program Files\Python311\Lib\site-packages\IPython\core\interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prwa.txt'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 10
# ...

# %%
import sys
import logging
logging.basicConfig(level=logging.INFO)
try:
    f = open('prwa.txt')
    #perform file operation

except:
    #print('Something went wrong');
    logging.info(sys.exc_info())
# Out:
# INFO:root:(<class 'FileNotFoundError'>, FileNotFoundError(2, 'No such file or directory'), <traceback object at 0x0000028F8779A480>)

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.debug("This is a debug message")

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

jk = pd.read_csv('nyc_weather.csv')
jk.head(10)
#jk.tail(10)
jk
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
#NAN : not a no.

jk.Events.unique()
jk.Humidity
# Out:
# 0     52
# 1     46
# 2     47
# 3     44
# 4     41
# 5     35
# 6     33
# 7     64
# 8     77
# 9     71
# 10    37
# 11    53
# 12    42
# 13    47
# 14    62
# 15    70
# 16    66
# 17    53
# 18    42
# 19    49
# 20    45
# 21    41
# 22    78
# 23    53
# 24    54
# 25    56
# 26    45
# 27    51
# 28    50
# 29    46
# 30    52
# Name: Humidity, dtype: int64

# %%
jk.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
jk.count() #columnwise record count
#jk.Temperature.count #individual column count
#jk.describe()  #it will give details of matrix
# Out:
# EST                     31
# Temperature             31
# DewPoint                31
# Humidity                31
# Sea Level PressureIn    31
# VisibilityMiles         31
# WindSpeedMPH            28
# PrecipitationIn         31
# CloudCover              31
# Events                   9
# WindDirDegrees          31
# dtype: int64

# %%
jk.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
jk.shape
# Out:
# (31, 11)

# %%
jk.WindSpeedMPH
# Out:
# 0      8.0
# 1      7.0
# 2      8.0
# 3      9.0
# 4      5.0
# 5      4.0
# 6      2.0
# 7      4.0
# 8      8.0
# 9      NaN
# 10     NaN
# 11     6.0
# 12    10.0
# 13     5.0
# 14     5.0
# 15     7.0
# 16     6.0
# 17    12.0
# 18    11.0
# 19     6.0
# 20     6.0
# 21     NaN
# 22    16.0
# 23     6.0
# 24     3.0
# 25     7.0
# 26     7.0
# 27     5.0
# 28     8.0
# 29     7.0
# 30     5.0
# Name: WindSpeedMPH, dtype: float64

# %%
jk.WindSpeedMPH.isna() #row 9,10,21 are NAN
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: WindSpeedMPH, dtype: bool

# %%
jk.WindSpeedMPH.isna().sum() #will tell you that how many NAN is available in this column
# Out:
# np.int64(3)

# %%
jk.dtypes
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
jk.Events.unique
# Out:
# <bound method Series.unique of 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object>

# %%
jk.Events.describe()
# Out:
# count        9
# unique       3
# top       Rain
# freq         4
# Name: Events, dtype: object

# %%
#get maximum temperature
print(jk['Temperature'].max())
# Out:
# 50

# %%
jk['Humidity'].min()
# Out:
# np.int64(33)

# %%
jk1 = jk['Temperature'] > 30
jk1
jk1.sum() #total no.of temp more than 30
jk1.head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Temperature, dtype: bool

# %%
#To know which day it rains

jk['EST'][jk['Humidity']==70]
# Out:
# 15    1/16/2016
# Name: EST, dtype: object

# %%
jk['EST'][jk['Humidity']>=70]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 22    1/23/2016
# Name: EST, dtype: object

# %%
jk['EST'][jk['WindSpeedMPH']==7.0][jk['Humidity']>=70]
# Out:
# 15    1/16/2016
# Name: EST, dtype: object

# %%
jk
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
jk.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
jk.head(10)
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   1/1/2016           38        23        52                 30.03
# 1   1/2/2016           36        18        46                 30.02
# 2   1/3/2016           40        21        47                 29.86
# 3   1/4/2016           25         9        44                 30.05
# 4   1/5/2016           20        -3        41                 30.57
# 5   1/6/2016           33         4        35                 30.50
# 6   1/7/2016           39        11        33                 30.28
# 7   1/8/2016           39        29        64                 30.20
# 8   1/9/2016           44        38        77                 30.16
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# ...

# %%
lst = [10,20,30,40,50,60]
print(type(lst))
s = pd.Series(lst,index=('1st',2,'2nd',3,'3rd',4))
print(s)
# Out:
# <class 'list'>
# 1st    10
# 2      20
# 2nd    30
# 3      40
# 3rd    50
# 4      60
# dtype: int64

# %%
l1 = [1,2,3]

ser = pd.Series(l1,index=['1st',2,'3rd'])
print(ser,type(ser))
# Out:
# 1st    1
# 2      2
# 3rd    3
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
print(s.loc[0:4])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s = pd.Series(lst,dtype='float32')
print(s,type(s))
s[3]
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4    50.0
# 5    60.0
# dtype: float32 <class 'pandas.core.series.Series'>
# np.float32(40.0)

# %%
s.shape
# Out:
# (6,)

# %%
aji = [10,"Ajin",34.56,"DEV"]

s =  pd.Series(aji,index=("RollNo","Name","Marks","Desig"))

print(s,type(s))
s['RollNo']
# Out:
# RollNo       10
# Name       Ajin
# Marks     34.56
# Desig       DEV
# dtype: object <class 'pandas.core.series.Series'>
# 10

# %%
d1 = {"sub" : "Python", "sub2" : "Java" , "sub3" : "Data Science"}
print(d1,type(d1))
# Out:
# {'sub': 'Python', 'sub2': 'Java', 'sub3': 'Data Science'} <class 'dict'>

# %%
d1.items()
# Out:
# dict_items([('sub', 'Python'), ('sub2', 'Java'), ('sub3', 'Data Science')])

# %%
d1.keys()
# Out:
# dict_keys(['sub', 'sub2', 'sub3'])

# %%
d1.values()
# Out:
# dict_values(['Python', 'Java', 'Data Science'])

# %%
d1["sub"]
# Out:
# 'Python'

# %%
import numpy as np

# %%
num = np.array([1,2,3])
pd.Series(num)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# CREATING AND OBJECT DATAFRAME BY USING LIST/TUPLE

# %%
lst = [[1,0,1,3] , [10,20,30,0],[10,20,30,40]]

df = pd.Series(lst)
print(df)
# Out:
# 0        [1, 0, 1, 3]
# 1     [10, 20, 30, 0]
# 2    [10, 20, 30, 40]
# dtype: object

# %%
lst = [[10,'RS'],[20,'JG'],[30,'MCK'],[40,'TRA']]

df= pd.DataFrame(lst)

print(df)
# Out:
#     0    1
# 0  10   RS
# 1  20   JG
# 2  30  MCK
# 3  40  TRA

# %%
df.iloc[1:,:]
# Out:
#     0    1
# 1  20   JG
# 2  30  MCK
# 3  40  TRA

# %%
df.iloc[3,1]
# Out:
# 'TRA'

# %%
lst = [[10,'RS'],[20,'JG'],[30,'MCK'],[40,'TRA']]

df = pd.DataFrame(lst, columns=["Rno","Name"],index= [1,2,"three","four"])
print(df)
# Out:
#        Rno Name
# 1       10   RS
# 2       20   JG
# three   30  MCK
# four    40  TRA

# %%
tpl = (("Rossum", 75),("Gosling",85),("Travis",65),("Ritche",95),("MCKinney",60))

df = pd.DataFrame(tpl, index=[1,'@',3,4,5],columns =['Name','Age'])

print(df)
# Out:
#        Name  Age
# 1    Rossum   75
# @   Gosling   85
# 3    Travis   65
# 4    Ritche   95
# 5  MCKinney   60

# %%
df['salary'] = [1,2,3,4,5]

# %%
df
# Out:
#        Name  Age  salary
# 1    Rossum   75       1
# @   Gosling   85       2
# 3    Travis   65       3
# 4    Ritche   95       4
# 5  MCKinney   60       5

# %%
df.drop("salary",axis=1,inplace = True)

# %%
df
# Out:
#        Name  Age
# 1    Rossum   75
# @   Gosling   85
# 3    Travis   65
# 4    Ritche   95
# 5  MCKinney   60

# %% [markdown]
# CREATING AN OBJECT DATAFRAME BY USING DICT OBJECT

# %%
dictdata = {"Names":["Rossum","Gosling","Ritche","McKinney"],"Subjects":["Pyhton","Java","C","Pandas"],"Ages":[65,80,85,55] }
#dictdata.values()
print(dictdata)
# Out:
# {'Names': ['Rossum', 'Gosling', 'Ritche', 'McKinney'], 'Subjects': ['Pyhton', 'Java', 'C', 'Pandas'], 'Ages': [65, 80, 85, 55]}

# %%
df = pd.DataFrame(dictdata)
print(df)
# Out:
#       Names Subjects  Ages
# 0    Rossum   Pyhton    65
# 1   Gosling     Java    80
# 2    Ritche        C    85
# 3  McKinney   Pandas    55

# %%
df = pd.DataFrame(dictdata)
df.shape
# Out:
# (4, 3)

# %%
df = pd.DataFrame(dictdata,index = [1,2,3,'e'])
print(df)
# Out:
#       Names Subjects  Ages
# 1    Rossum   Pyhton    65
# 2   Gosling     Java    80
# 3    Ritche        C    85
# e  McKinney   Pandas    55

# %% [markdown]
# # CREATING AN OBJECT DATAFRAME USING SERIES OBJECT

# %%
l1 = [10,20,30,40,50]

sdata = pd.Series(l1)
print(sdata)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
df = pd.DataFrame(sdata , columns = ["number"])
print(df)
# Out:
#    number
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
d1 = {"totmark" : [100,110,120,130],"ExtMarks":[80,75,65,90]}
df = pd.DataFrame(d1,index = [1,2,3,4])
(df)
# Out:
#    totmark  ExtMarks
# 1      100        80
# 2      110        75
# 3      120        65
# 4      130        90

# %%
df.iloc[3:,:]
# Out:
#    totmark  ExtMarks
# 4      130        90

# %%
# ADD NEW COLUMN NAME TO DATAFRAME

df['Sum'] = df['totmark'] + df['ExtMarks']
df
# Out:
#    totmark  ExtMarks  Sum
# 1      100        80  180
# 2      110        75  185
# 3      120        65  185
# 4      130        90  220

# %%
df.drop('c3',axis=1, inplace=True)
df
# Out:
#    totmark  ExtMarks
# 1      100        80
# 2      110        75
# 3      120        65
# 4      130        90

# %%
df
# Out:
#    totmark  ExtMarks  Sum
# 1      100        80  180
# 2      110        75  185
# 3      120        65  185
# 4      130        90  220

# %%
df['New Column'] = [1,2,3,4]

# %%
df
# Out:
#    totmark  ExtMarks  Sum  New Column
# 1      100        80  180           1
# 2      110        75  185           2
# 3      120        65  185           3
# 4      130        90  220           4

# %%
df ['sub'] = df['totmark'] - df['ExtMarks']

# %%
df
# Out:
#    totmark  ExtMarks  Sum  New Column  sub
# 1      100        80  180           1   20
# 2      110        75  185           2   35
# 3      120        65  185           3   55
# 4      130        90  220           4   40

# %%
df.drop('New Column', axis=1, inplace = True)

# %%
df
# Out:
#    totmark  ExtMarks  Sum  sub
# 1      100        80  180   20
# 2      110        75  185   35
# 3      120        65  185   55
# 4      130        90  220   40

# %%
df['New Column'] = [1,2,3,4]
df
# Out:
#    totmark  ExtMarks  Sum  sub  New Column
# 1      100        80  180   20           1
# 2      110        75  185   35           2
# 3      120        65  185   55           3
# 4      130        90  220   40           4

# %%
df ['new data'] = ['1st', '2nd','3rd','4rth']
df
# Out:
#    totmark  ExtMarks  Sum  sub  New Column new data
# 1      100        80  180   20           1      1st
# 2      110        75  185   35           2      2nd
# 3      120        65  185   55           3      3rd
# 4      130        90  220   40           4     4rth

# %%
df['Roll_No'] = range(1,5)

# %%
df
# Out:
#    totmark  ExtMarks  Sum  sub  New Column new data  Roll_No
# 1      100        80  180   20           1      1st        1
# 2      110        75  185   35           2      2nd        2
# 3      120        65  185   55           3      3rd        3
# 4      130        90  220   40           4     4rth        4

# %%
#changing the column order
df = df[['Roll_No','totmark','ExtMarks','Sum','New Column','new data']]

# %%
df
# Out:
#    Roll_No  totmark  ExtMarks  Sum  New Column new data
# 1        1      100        80  180           1      1st
# 2        2      110        75  185           2      2nd
# 3        3      120        65  185           3      3rd
# 4        4      130        90  220           4     4rth

# %% [markdown]
# # ASSIGNMENT : HW : HOW TO JOIN TWO TABLES USING DATAFRAME

# %% [markdown]
# # SORTING THE DATAFRAME DATA

# %%
df ['Name'] = ["Ajin","Pradul","Prajual","Sachin"]
df
# Out:
#    Roll_No  totmark  ExtMarks  Sum  New Column new data     Name
# 1        1      100        80  180           1      1st     Ajin
# 2        2      110        75  185           2      2nd   Pradul
# 3        3      120        65  185           3      3rd  Prajual
# 4        4      130        90  220           4     4rth   Sachin

# %%
df = df.sort_values(["Name"],ascending=False)
df
# Out:
#    Roll_No  totmark  ExtMarks  Sum  New Column new data     Name
# 4        4      130        90  220           4     4rth   Sachin
# 3        3      120        65  185           3      3rd  Prajual
# 2        2      110        75  185           2      2nd   Pradul
# 1        1      100        80  180           1      1st     Ajin

# %%
df = df.sort_values(["ExtMarks"],ascending=True)
df
# Out:
#    Roll_No  totmark  ExtMarks  Sum  New Column new data     Name
# 3        3      120        65  185           3      3rd  Prajual
# 2        2      110        75  185           2      2nd   Pradul
# 1        1      100        80  180           1      1st     Ajin
# 4        4      130        90  220           4     4rth   Sachin

# %%
import pandas as pd

df = pd.read_csv('IPL Matches 2008-2020.csv')
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
#Scientific PY
pip install skipy
# Out:
# ...
#      -------------------------------------- 139.9/139.9 kB 4.1 MB/s eta 0:00:00
# ...
#      --------------------------------------- 13.3/13.3 MB 10.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.4/9.4 MB 12.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 293.3/293.3 kB 9.1 MB/s eta 0:00:00
# ...
#      --------------------------------------- 13.5/13.5 MB 11.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 84.8/84.8 kB 5.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 96.9/96.9 kB 5.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 212.3/212.3 kB 6.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 160.1/160.1 kB 9.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 499.2/499.2 kB 7.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 50.2/50.2 kB ? eta 0:00:00
# ...
#      ------------------------------------- 181.3/181.3 kB 11.4 MB/s eta 0:00:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64
